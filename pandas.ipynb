# %%
import pandas as pd
import numpy as np

# %%
labels = ["a","b","c"]
arr = np.array([10,20,30])
dict = {1:10,2:20,3:30}
MY_LIST = [10,20,30]

# %%
pd.Series(MY_LIST,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(dict)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64

# %% [markdown]
# DATA_FRAMES

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}

df = pd.DataFrame(data)
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# DATA FRAME USING THE LIST

# %%
df['City']
# Out:
# 0    New York
# 1       Paris
# 2      Berlin
# 3      London
# Name: City, dtype: str

# %%
df["profession"] = ["doctor","enginner","teacher","berozgaar"]
df
# Out:
#     Name  Age      City  Salary profession
# 0   John   28  New York   65000     doctor
# 1   Anna   34     Paris   70000   enginner
# 2  Peter   29    Berlin   62000    teacher
# 3  Linda   42    London   85000  berozgaar

# %%
df.drop("profession", axis = 1 , inplace= True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df.drop("profession", axis = 1 , inplace= True)
#
# File ~\OneDrive\Desktop\ml_model\.venv\Lib\site-packages\pandas\core\frame.py:6302, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6298                 weight  250.0   150.0
#    6299         falcon  speed   320.0   250.0
#    6300                 weight  1.0     0.8
#    6301         """
# -> 6302         return super().drop(
#    6303             labels=labels,
#    6304             axis=axis,
#    6305             index=index,
#
# File ~\OneDrive\Desktop\ml_model\.venv\Lib\site-packages\pandas\core\generic.py:4632, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4628         obj = self
#    4629
#    4630         for axis, labels in axes.items():
#    4631             if labels is not None:
# -> 4632                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4633
#    4634         if inplace:
#    4635             self._update_inplace(obj)
#
# File ~\OneDrive\Desktop\ml_model\.venv\Lib\site-packages\pandas\core\generic.py:4674, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4670                 if not isinstance(axis, MultiIndex):
#    4671                     raise AssertionError("axis must be a MultiIndex")
#    4672                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4673             else:
# -> 4674                 new_axis = axis.drop(labels, errors=errors)
#    4675             indexer = axis.get_indexer(new_axis)
#    4676
#    4677         # Case for non-unique axis
#
# File ~\OneDrive\Desktop\ml_model\.venv\Lib\site-packages\pandas\core\indexes\base.py:7268, in Index.drop(self, labels, errors)
#    7266 if mask.any():
#    7267     if errors != "ignore":
# -> 7268         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7269     indexer = indexer[~mask]
#    7270 return self.delete(indexer)
#
# KeyError: "['profession'] not found in axis"

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df.loc[[2,3]][["Name","Age"]]
# Out:
#     Name  Age
# 2  Peter   29
# 3  Linda   42

# %%
df[(df['Age'] > 30) & (df['City'] == 'Paris')]
# Out:
#    Name  Age   City  Salary
# 1  Anna   34  Paris   70000
